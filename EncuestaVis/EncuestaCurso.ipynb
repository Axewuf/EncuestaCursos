# %%
import numpy as np
import json
import textwrap
import re
import pandas as pd
import matplotlib.pyplot as plt
import spacy
# spacy.cli.download("es_core_news_sm")
from PIL import Image
from wordcloud import WordCloud
from ipywidgets import widgets, Checkbox, IntSlider, SelectionSlider
from IPython.display import display, clear_output

#Setting up the display mask for wordcloud
words_mask = np.array(Image.open("assets/silhouette.jpg").convert("L")) #Loading a black and white image with convert("L") to transform it to greyscale
words_mask = np.where(words_mask > 128, 255, 0) #Clamping the greyscale values to 0 or 255

#Loading data file
data = pd.read_excel('assets/ResultadosFinales Public.xlsx', header=[0, 1], index_col=[0, 1]) #Loading the survey data from an excel doc that has its first two rows as headers

# %%
question1_text = data.columns[23][0][3:] #Question 1 - q1
question2_text = data.columns[49][0][4:] #Question 2 - q2
data.columns = data.columns.droplevel(0) #Removing top header with the question's sentence
data = data[data['Total de Respuestas']>0] #Filtering the rows that don't have any survey answers
data = data.iloc[:, [23,24,25,26,27,48,49,50,51,52,53]] #From 23-27 are q1 answers, 48-52 are q2 answers, and 53 are the comments

#Multiplying each question answer times a category value and diving by total answers
data['q1_mean'] = (data.iloc[:, 0:5].mul([0,1,2,3,4], axis=1).sum(axis=1) / data.iloc[:, 0:5].sum(axis=1)).round() 
data['q2_mean'] = (data.iloc[:, 5:10].mul([0,1,2,3,4], axis=1).sum(axis=1) / data.iloc[:, 5:10].sum(axis=1)).round()

data.head()
# Out:
# ID del Curso  Siempre  Casi siempre  Algunas veces  Casi nunca  Nunca  \
# 0 32896-1         7.0           4.0            3.0         1.0    0.0
# 1 32896-10        3.0           4.0            5.0         1.0    3.0
# 2 32896-11       14.0           1.0            1.0         0.0    0.0
# 3 32896-2         5.0           9.0            2.0         1.0    0.0
# 4 32896-3        10.0           2.0            1.0         0.0    0.0
#
# ID del Curso  Muy buena  Buena  Regular  Mala  Muy mala  \
# 0 32896-1          10.0    4.0      1.0   0.0       0.0
# 1 32896-10          3.0    4.0      4.0   1.0       1.0
# 2 32896-11         14.0    2.0      0.0   0.0       0.0
# 3 32896-2           9.0    6.0      3.0   0.0       0.0
# 4 32896-3          11.0    2.0      0.0   0.0       0.0
#
# ID del Curso                                         Comentario  q1_mean  \
# 0 32896-1     #1. Nada\n#2. En que trate de hacer los temas ...      1.0
# ...

# %%
#Loading stop words
with open("assets/stop_words_spanish_no_verbs.json", "r", encoding="utf-8") as file:
    stop_words_dic = json.load(file)
stop_words = sum(stop_words_dic.values(), []) #Combining all the lists from the dictionary into one single list
pattern_separator = "[" + re.escape("".join(stop_words_dic['punctuation'])) + "]" #Pattern of delimiters to split words by

nlp = spacy.load("es_core_news_sm")
comments = data.iloc[:,10]
filtered_lemmatized_list = []

for comment in comments:
    tokenized = nlp(str(comment)) #Tokenizes and lemmatizes the comment
    lemmas = [token.lemma_ for token in tokenized if 'http' not in token.lemma_ and '--' not in token.lemma_] #Getting the lemmas in string form and filtering urls and lines
    lemmas = [part for word in lemmas for part in re.split(pattern_separator, word) if part] #Split words that are conjoined with punctuation symbols, and spaces in some cases ("confírmese" es convertido a "confirmar él")
    lemmas = [word for word in lemmas if word not in stop_words and not word.isdigit()] #Remove words that are stop_words or numbers
    filtered_lemmatized_list.append(lemmas)

data['Comments_lemmatized'] = filtered_lemmatized_list
data['number_of_words'] = data['Comments_lemmatized'].apply(lambda word_list: len(word_list))

data.head()
# Out:
# ID del Curso  Siempre  Casi siempre  Algunas veces  Casi nunca  Nunca  \
# 0 32896-1         7.0           4.0            3.0         1.0    0.0
# 1 32896-10        3.0           4.0            5.0         1.0    3.0
# 2 32896-11       14.0           1.0            1.0         0.0    0.0
# 3 32896-2         5.0           9.0            2.0         1.0    0.0
# 4 32896-3        10.0           2.0            1.0         0.0    0.0
#
# ID del Curso  Muy buena  Buena  Regular  Mala  Muy mala  \
# 0 32896-1          10.0    4.0      1.0   0.0       0.0
# 1 32896-10          3.0    4.0      4.0   1.0       1.0
# 2 32896-11         14.0    2.0      0.0   0.0       0.0
# 3 32896-2           9.0    6.0      3.0   0.0       0.0
# 4 32896-3          11.0    2.0      0.0   0.0       0.0
#
# ID del Curso                                         Comentario  q1_mean  \
# 0 32896-1     #1. Nada\n#2. En que trate de hacer los temas ...      1.0
# ...

# %%
valores = [0,1,2,3,4]
q1_keys = list(data.iloc[:, [0,1,2,3,4]].columns)
q1_options = {k: v for k, v in zip(q1_keys, valores)}
q2_keys = list(data.iloc[:, [5,6,7,8,9]].columns)
q2_options = {k: v for k, v in zip(q2_keys, valores)}

widget_q1_checkbox = Checkbox(value=False, description="Enable filter", disabled=False)
widget_q2_checkbox = Checkbox(value=False, description="Enable filter", disabled=False)
widget_q1_slider = SelectionSlider(value=q1_keys[2], options=q1_keys, description="Question's 1 mean is closer to:", style={'description_width': '200px'}, layout=widgets.Layout(width='500px'))
widget_q2_slider = SelectionSlider(value=q2_keys[2], options=q2_keys, description="Question's 2 mean is closer to:", style={'description_width': '200px'}, layout=widgets.Layout(width='500px'))
widget_letter_slider = IntSlider(value=3, min=1, max=30, step=1, description='Minimum letters per word:', disabled=False, continuous_update=False, orientation='horizontal', readout=True, readout_format='d', 
                                 style={'description_width': '200px'}, layout=widgets.Layout(width='1000px'))

# Titles
q1_wrapped_title = "\n".join(textwrap.wrap(question1_text, width=50))
q2_wrapped_title = "\n".join(textwrap.wrap(question2_text, width=50))

def plot_functions(q1_checkbox, q1_slider, q2_checkbox, q2_slider, letter_slider):
    with output:
        clear_output(wait=True)
        fig, axes = plt.subplots(2, 2, figsize=(15, 10))
        plt.subplots_adjust(hspace=0.3)
        axes = axes.flatten()
        
        # FILTERING DATA
        filtered_data = data
        if q1_checkbox:
            filtered_data = filtered_data[filtered_data['q1_mean']==q1_options[q1_slider]]
        if q2_checkbox:
            filtered_data = filtered_data[filtered_data['q2_mean']==q2_options[q2_slider]]

        # QUESTION 1
        data_q1 = filtered_data.iloc[:, [0,1,2,3,4]]
        data_q1 = data_q1.sum()
        total_sum_q1 = data_q1.sum()
        data_q1 = (data_q1/total_sum_q1*100).dropna()
        opacity = 1 if q1_checkbox else 0.2
        axes[0].bar(data_q1.index, data_q1.values, color='blue', alpha=opacity)
        axes[0].text(0.5, 1.1, q1_wrapped_title, ha='center', fontsize=12, transform=axes[0].transAxes)
        # QUESTION 2
        data_q2 = filtered_data.iloc[:, [5,6,7,8,9]]
        data_q2 = data_q2.sum()
        total_sum_q2 = data_q2.sum()
        data_q2 = (data_q2/total_sum_q2*100).dropna()
        opacity = 1 if q2_checkbox else 0.2
        wedges, _, _ = axes[1].pie(data_q2.values, labels=data_q2.index, autopct='%1.1f%%')
        [wedge.set_alpha(opacity) for wedge in wedges]
        axes[1].text(0.5, 1.1, q2_wrapped_title, ha='center', fontsize=12, transform=axes[1].transAxes)
        # WORD CLOUD
        words_all = data['Comments_lemmatized'].apply(lambda word_list: [word for word in word_list if len(word) >= letter_slider])
        words_all = words_all[words_all.apply(lambda x: len(x) > 0)]
        words_all = words_all.apply(" ".join)
        words_all = " ".join(words_all.values)
        if words_all:
            wc = WordCloud(background_color="white", max_words=100, mask=words_mask, contour_width=3, contour_color='steelblue')
            wc = wc.generate(words_all)
            axes[2].imshow(wc, interpolation="bilinear")
        else:
            axes[2].imshow(words_mask, cmap='gray', interpolation="bilinear")
        axes[2].axis("off")
        # SCATTER PLOT
        num_words = filtered_data['number_of_words']
        x_jittered = [1]*len(num_words) + np.random.normal(loc=0, scale=0.06, size=len(num_words))
        axes[3].scatter(x_jittered, num_words.values, color='blue', alpha=0.7, edgecolors='black', s=100)
        axes[3].set_xlabel("")
        axes[3].set_xticks([])
        axes[3].set_title("How many words were used in the comment section")
        plt.show()

def on_value_change(change):
    plot_functions(widget_q1_checkbox.value, widget_q1_slider.value, widget_q2_checkbox.value, widget_q2_slider.value, widget_letter_slider.value)
    
widget_q1_slider.observe(on_value_change, names="value")
widget_q1_checkbox.observe(on_value_change, names="value")
widget_q2_slider.observe(on_value_change, names="value")
widget_q2_checkbox.observe(on_value_change, names="value")
widget_letter_slider.observe(on_value_change, names="value")

output = widgets.Output()

vbox_q1 = widgets.VBox([widget_q1_checkbox,widget_q1_slider], layout=widgets.Layout(margin='20px'))
vbox_q2 = widgets.VBox([widget_q2_checkbox,widget_q2_slider], layout=widgets.Layout(margin='20px'))
hbox_q = widgets.HBox([vbox_q1, vbox_q2])

vbox_final = widgets.VBox([hbox_q,widget_letter_slider], layout=widgets.Layout(margin='0px 20px 20px 20px'))


display(vbox_final, output)
plot_functions(widget_q1_checkbox.value, widget_q1_slider.value, widget_q2_checkbox.value, widget_q2_slider.value, widget_letter_slider.value)
# Out:
# ...
# Output()
